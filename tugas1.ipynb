# %%
import matplotlib.pyplot as plt

beras	= 11400	
minyak = 	12700
ayam =	3400	
telur = 	21800	
popok	= 27000	
sabun_cuci = 	1800	
buah_anggur	= 3800	
roti_tawar	= 8500	
tissu =	6400	
mie_instan =	2200	

print("===belanjaan tia===")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
buah_anggur_tia = 4
roti_tawar_tia = 2
mie_instan_tia = 12

jb_tia = (beras_tia * beras) + (ayam_tia * (ayam * 10 )) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * (buah_anggur * 10)) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
print("maka jumlah belanjaan tia " + str(jb_tia) + " rupiah")



print("")
print("")


print("===belanjaan hana===")
minyak_hana = 2
ayam_hana = 5
telur_hana = 5
sabun_cuci_hana = 3
buah_anggur_hana = 8
roti_tawar_hana = 3
tissu_hana = 2
mie_instan_hana = 20

diskon = 90

jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam  ) + (telur_hana * telur ) * (sabun_cuci_hana * sabun_cuci) + (buah_anggur_hana * buah_anggur) + (roti_tawar_hana * roti_tawar) + (tissu_hana * tissu) + (mie_instan_hana * mie_instan_hana)
print("maka jumlah belanjaan hana " + str(jb_hana) + " rupiah")


print("")
print("")


print("===belanjaan widia===")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_anggur_widia = 5
tissu_widia = 3
mie_instan_widia = 16


jb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (buah_anggur_widia * buah_anggur) + (tissu_widia * tissu) + (mie_instan_widia * mie_instan)
print("maka jumlah belanjaan widia " + str(jb_widia) + " rupiah")


print("")
print("")


print("===belanjaan romi===")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_cuci_romi = 8
mie_instan_romi = 8


jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_cuci_romi * sabun_cuci) + (mie_instan_romi * mie_instan)
print("maka jumlah belanjaan romi " + str(jb_romi) + " rupiah")


print("")
print("")


print("===belanjaan samsul===")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_anggur_samsul = 7
tissu_samsul = 5
mie_instan_samsul = 10


jb_samsul = (ayam_samsul * (ayam * 10)) + (telur_samsul * telur) + (popok_samsul * popok) + (buah_anggur_samsul * buah_anggur) + (tissu_samsul * tissu) + (mie_instan_samsul * mie_instan)
print("maka jumlah belanjaan samsul " + str(jb_samsul) + " rupiah")


print("")
print("")


print("===belanjaan dimas===")
ayam_dimas = 5
popok_dimas = 5
sabun_cuci_dimas = 4
buah_anggur_dimas = 3
roti_tawar_dimas = 5
mie_instan_dimas = 5


jb_dimas = (ayam_dimas * ayam ) + (popok_dimas * popok) + (sabun_cuci_dimas * sabun_cuci) + (buah_anggur_dimas * buah_anggur) + (roti_tawar_dimas * roti_tawar) + (mie_instan_dimas * mie_instan)
print("maka jumlah belanjaan dimas " + str(jb_dimas) + " rupiah")

print("")

print("==soal 3==")
max = [284475]
print("maka jumlah belanjaan paling besar setelah diskon adalah dimas rp. " + str(max))

print("==soal 4==")
tenpersen = {"hana" : "rp. 173880"}
print("makan yang mendapatkan diskon 10persen adalah : " + str(tenpersen))
# Out:
# ===belanjaan tia===
# maka jumlah belanjaan tia 383400 rupiah
#
#
# ===belanjaan hana===
# maka jumlah belanjaan hana 588711500 rupiah
#
#
# ===belanjaan widia===
# maka jumlah belanjaan widia 119300 rupiah
#
#
# ===belanjaan romi===
# maka jumlah belanjaan romi 221700 rupiah
#
#
# ===belanjaan samsul===
# maka jumlah belanjaan samsul 323800 rupiah
#
#
# ===belanjaan dimas===
# maka jumlah belanjaan dimas 224100 rupiah
#
# ==soal 3==
# maka jumlah belanjaan paling besar setelah diskon adalah dimas rp. [284475]
# ==soal 4==
# makan yang mendapatkan diskon 10persen adalah : {'hana': 'rp. 173880'}
