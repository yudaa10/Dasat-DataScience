# %%
import matplotlib.pyplot as plt

# %%
from IPython.lib.display import join
from matplotlib.figure import backends
print("===Soal No 1===")
burger = 24000
pizza  =  52000
dimsum = 30000
ekkado  = 7500
milkshake = 10000
eskrim = 15000

print("===belanjaan semua===")
burger_semua = 6
pizza_semua = 3
dimsum_semua = 4
ekkado_semua = 4
milkshake_semua = 2
eskrim_semua = 5

js = (burger_semua * burger) + (pizza_semua * pizza) + (dimsum_semua * dimsum) + (ekkado_semua * ekkado) + (milkshake_semua * milkshake) +(eskrim_semua * eskrim)
jm = (burger_semua + pizza_semua + dimsum_semua + ekkado_semua + milkshake_semua + eskrim_semua)
print("maka semua jumlah pesanan adalah : " + str(js))

print("")
print("")

print("===Soal No 2===")
f1 = (burger_semua / jm) * 100
f2 = (pizza_semua / jm) * 100
f3 = (dimsum_semua / jm) * 100
f4 = (eskrim_semua / jm) * 100
f5 = (milkshake_semua / jm) * 100
f6 = (ekkado_semua / jm) * 100

print("burger : " + str(f1) +'%')
print("pizza : " + str(f2)  +'%')
print("dimsum : " + str(f3)  +'%')
print("eskrim : " + str(f4)  +'%')
print("milkshake : " + str(f5)  +'%')
print("ekkado : " + str(f6)  +'%')
print("")
  
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
makanan = ['burger','pizza','dimsum', 'eskrim','milkshake','ekkado']
harga =  [25.0, 12.5, 16.666666666666664,  20.833333333333336,  8.333333333333332, 16.666666666666664]                                                  
ax.pie(harga,labels=makanan,autopct='%1.2f%%') 
plt.show()  
print("")

print("===Soal No 3===")
print(" ahnmad ")
burger_a = 4
pizza_a = 2
uang_a = 200000
jml_a = (0.70 * ((burger_a * 24000) + (pizza_a * 52000))) + (7.5 * 2000) - 5000
disc = uang_a - jml_a
print("maka total belanjaan ahmad adalah : rp. " + str(jml_a))
print("maka total kembalian ahmad adalah : rp. " + str(disc))
print("") 

print(" beni ")
dimsum_b = 3
eskrim_b = 1
milkshake_b = 2
uang_b = 150000
jml_b = (0.70 * ((dimsum_b * 30000) + (eskrim_b * 15000) + (milkshake_b * 10000))) + (4 * 1800) - 5000
disc = uang_b - jml_b
print("maka total belanjaan ahmad adalah : rp. " + str(jml_b))
print("maka total kembalian ahmad adalah : rp. " + str(disc))
print("")

print(" citra ")
eskrim_c = 3
uang_c = 60000
jml_c = (eskrim_c * 15000) + (8 * 2000) - 5000
disc = uang_c - jml_c
print("maka total belanjaan ahmad adalah : rp. " + str(jml_c))
print("maka total kembalian ahmad adalah : rp. " + str(disc))
print("")

print(" dadang ")
burger = 2
dimsum = 1
uang_d = 100000
jml_d = (0.80 * ((burger * 24000) + (dimsum * 30000))) + (5 * 1800) - 5000
disc = uang_d - jml_d
print("maka total belanjaan ahmad adalah : rp. " + str(jml_d))
print("maka total kembalian ahmad adalah : rp. " + str(disc))
print("")

print(" epen ")
ekkado = 4
eskrim = 1
pizza = 1
uang_e = 100000
jml_e = (0.70 * ((ekkado * 7500) + (eskrim * 15000) + (pizza * 52000))) + (12 * 2200) - 5000
disc = uang_e - jml_e
print("maka total belanjaan ahmad adalah : rp. " + str(jml_e))
print("maka total kembalian ahmad adalah : rp. " + str(disc))
print("")
