# %%
import matplotlib.pyplot as plt

# %%
print("soal 1")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [5,18,30,7,16,19,12]
c = ['red','green','blue','red','green','blue','black']
plt.title("SISWA YANG MENGIKUTI EKSTAKU DI KELAS 10 SMK AL-MADANI GARUT")
ax.bar(eskul, siswa, color = c)            
plt.show()

# %%
print("soal 2")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['kelas 10','kelas 11','kelas 12']
siswa = [107,100,80,]
c = ['red','blue','black']
plt.title("JUMLAH SISWA YANG MENGIKUTI SETIAP ESKULNYA SMK AL-MADANI GARUT")
ax.bar(eskul, siswa, color = c)            
plt.show()
print("")

pas_a = 5
pas_b = 21
pas_c = 6
jumlah_pas = pas_a + pas_b + pas_c
print("maka jumlah keseluruhan paskibra kls10,kls11,kls12 = " + str(jumlah_pas))
print("")
pmr_a = 18
pmr_b = 4
pmr_c = 12
jumlah_pmr = pmr_a + pmr_b + pmr_c
print("maka jumlah keseluruhan pmr kls10,kls11,kls12 = " + str(jumlah_pmr))
print("")
pra_a = 30
pra_b = 8
pra_c = 24
jumlah_pra = pra_a + pra_b + pra_c
print("maka jumlah keseluruhan pramuka kls10,kls11,kls12 = " + str(jumlah_pra))
print("")
futsal_a = 7
futsal_b = 29
futsal_c = 15
jumlah_futsal = futsal_a + futsal_b + futsal_c
print("maka jumlah keseluruhan futsal kls10,kls11,kls12 = " + str(jumlah_futsal))
print("")
volly_a = 16
volly_b = 10
volyy_c = 12
jumlah_volly = volly_a + volly_b + pas_c
print("maka jumlah keseluruhan volly kls10,kls11,kls12 = " + str(jumlah_volly))
print("")
kes_a = 19
kes_b = 18
kes_c = 4
jumlah_kes = kes_a + kes_b + kes_c
print("maka jumlah keseluruhan kesenian kls10,kls11,kls12 = " + str(jumlah_kes))
print("")
rohis_a = 12
rohis_b = 10
rohis_c = 7
jumlah_rohis = rohis_a + rohis_b + rohis_c
print("maka jumlah keseluruhan rohis kls10,kls11,kls12 = " + str(jumlah_rohis))

# %%
print("soal 3")
print("")
pas = 32
pmr = 34
pra = 62
put = 51
pol = 38
seni = 41
rohis = 38
jumlah =  pas + pmr + pra + +put + pol + seni + rohis 
print("maka jumlah keseluruhan yang mengikuti ekskul adalah :" + str(jumlah))

paskibra_a = 5
paskibra_b = 21
paskibra_c = 6

jumlah = paskibra_a + paskibra_b + paskibra_c
print("maka jumlahnya : " + str(jumlah))

print("")

pmr_a = 18
pmr_b = 4
pmr_c = 12

jumlah = pmr_a + pmr_b + pmr_c
print("maka jumlahnya : " + str(jumlah))


print("")

p_a = 30
p_b = 8
p_c = 24

jumlah = p_a + p_b + p_c
print("maka jumlahnya : " + str(jumlah))


print("")

k_a = 19
k_b = 18
k_c = 4

jumlah = k_a + k_b + k_c
print("maka jumlahnya : " + str(jumlah))

print("")

r_a = 12
r_b = 11
r_c = 7
jumlah = r_a + r_b + r_c
print("maka jumlahnya : " + str(jumlah))

print("")
pas = 32
pmr = 34
pra = 62
kes = 41
roh = 30

hasil = pas + pmr + pra + kes + roh
print("maka jumlah keseluruhan yang mengikuti eskul adalah  : " + str(hasil))

print("")

pu_a = 7
pu_b = 29
pu_c = 15

jumlah = pu_a + pu_b + pu_c
print("maka jumlah yang mengikuti eskul futsal : " + str(jumlah))

print("")

v_a = 16
v_b = 10
v_c = 12

jumlah = v_a + v_b + v_c
print("maka jumlah yang mengikuti eskul voli : " + str(jumlah))
print("")


kelas10 = 17
kelas11 = 8
kelas12 = 20

total = kelas10 + kelas11 + kelas12
print("maka total yang tidak mengikuti eskul adalah : " + str(total))

print("")
fut = 51
vol = 38

total = fut + vol
print("maka total yang mengikuti eskul olahraga adalah : " + str(total))

print("")
tm = 45
m = 199
olahraga = 89

total = tm / 333
jumlah = m / 333
jumlah_a = olahraga / 333
hasil = tm + m + olahraga
print("maka total keseluruhan adalah : " + str(hasil))
print("maka total persentasenya : " + str(total))
print("maka total persentasenya : " + str(jumlah))
print("maka total persentasenya : " + str(jumlah_a))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["Tidak Mengikuti", "Mengikuti", "Olahraga"]
jumlah = [13, 59, 26 ]
c = ['blue', 'green', 'red']
plt.title("Persentase keseluruhan")
plt.bar(eskul, jumlah, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ["Tidak Mengikuti", "Mengikuti", "Olahraga"]
jumlah = [13, 59, 26 ]
ax.pie(jumlah, labels=eskul,autopct='%1.2f%%')
plt.title("Persentase keseluruhan")
plt.show()

print("")
print("soal 4")
kelas10 = 17
kelas11 = 8
kelas12 = 20

total = kelas10 / 45
total_a = kelas11 / 45
total_b = kelas12 / 45
hasil = kelas10 + kelas11 + kelas12
print("Maka hasilnya adalah : " + str(hasil))
print("Maka hasilnya adalah : " + str(total))
print("Maka hasilnya adalah : " + str(total_a))
print("Maka hasilnya adalah : " + str(total_b))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ["Kelas10", "Kelas11", "Kelas12"]
jumlah = [37, 17, 44 ]
ax.pie(jumlah, labels=eskul,autopct='%1.2f%%')
plt.title("Persentase keseluruhan")
plt.show()

print("")
print("[SOAL5]")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["Paskibra", "Pmr", "Pramuka", "Futsal", "Volly", "Kesenian", "Rohis"]
jumlah = [5, 18, 30, 7, 16, 19, 12 ]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("Kelas 10")
plt.bar(eskul, jumlah, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ["Paskibra", "Pmr", "Pramuka", "Futsal", "Volly", "Kesenian", "Rohis"]
jumlah = [5, 18, 30, 7, 16, 19, 12 ]
ax.pie(jumlah, labels=eskul,autopct='%1.2f%%')
plt.title("Kelas 10")
plt.show()
print("")
print("============================================================================")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["Paskibra", "Pmr", "Pramuka", "Futsal", "Volly", "Kesenian", "Rohis"]
jumlah = [21, 4, 8, 29, 10, 18, 10 ]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("Kelas 11")
plt.bar(eskul, jumlah, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ["Paskibra", "Pmr", "Pramuka", "Futsal", "Volly", "Kesenian", "Rohis"]
jumlah = [21, 4, 8, 29, 10, 18, 10 ]
ax.pie(jumlah, labels=eskul,autopct='%1.2f%%')
plt.title("Kelas 11")
plt.show()

print("")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["Paskibra", "Pmr", "Pramuka", "Futsal", "Volly", "Kesenian", "Rohis"]
jumlah = [6, 12, 24, 15, 12, 4, 7 ]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("Kelas 12")
plt.bar(eskul, jumlah, color = c)
plt.show()
