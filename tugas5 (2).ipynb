# %%
import matplotlib.pyplot as plt

# %%
print("Soal No 1")
label1 = 32500000
label2 = 31000000
label3 = 42000000
label4 = 51500000
label5 = 27000000

utang1 = 0.08
utang2 = 0.04
utang3 = 0.12
utang4 = 0.11
utang5 = 0.03

karyawan_a = 20
karyawan_b = 14
karyawan_c = 28
karyawan_d = 42
karyawan_e = 18

gaji_a = 300000
gaji_b = 360000
gaji_c = 475000
gaji_d = 580000
gaji_e = 400000

asuransi = 75000 

jml_a = ((karyawan_a * gaji_a)) + ((karyawan_a * asuransi))
jml_b = ((karyawan_b * gaji_b)) + ((karyawan_b * asuransi))
jml_c = ((karyawan_c * gaji_c)) + ((karyawan_c * asuransi))
jml_d = ((karyawan_d * gaji_d)) + ((karyawan_d * asuransi))
jml_e = ((karyawan_e * gaji_e)) + ((karyawan_e * asuransi))
print(" jumlah pengeluaran gaji + asuransi setiap perusahaan a_xis   : Rp."+ str(jml_a))
print(" jumlah pengeluaran gaji + asuransi setiap perusahaan b_log   : Rp."+ str(jml_b))
print(" jumlah pengeluaran gaji + asuransi setiap perusahaan c_in    : Rp."+ str(jml_c))
print(" jumlah pengeluaran gaji + asuransi setiap perusahaan d_namic : Rp."+ str(jml_d))
print(" jumlah pengeluaran gaji + asuransi setiap perusahaan e_psilon: Rp."+ str(jml_e))

print("")

print("Soal No 2")
pajak = 0.03
pertahun = 12
jml_1 = ((label1 * pajak)) + ((utang1 * 280000000))
jml_2 = ((label2 * pajak)) + ((utang2 * 310000000))
jml_3 = ((label3 * pajak)) + ((utang3 * 420000000))
jml_4 = ((label4 * pajak)) + ((utang4 * 550000000))
jml_5 = ((label5 * pajak)) + ((utang5 * 340000000))
print(" maka total pajak dan utang adalah : Rp."+ str(jml_1))
print(" maka total pajak dan utang adalah : Rp."+ str(jml_2))
print(" maka total pajak dan utang adalah : Rp."+ str(jml_3))
print(" maka total pajak dan utang adalah : Rp."+ str(jml_4))
print(" maka total pajak dan utang adalah : Rp."+ str(jml_5))
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['red','black','blue','yellow']
plt.title("Total Pajak (pertahun) dan Utang setiap perusahaan")
ax.bar(perusahaan, pajak, color = c)            
plt.show()

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Total Pajak (pertahun) dan Utang setiap perusahaan") 
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [23375000.0,13330000.0,51660000.0,62045000.0,11010000.0]                                                
ax.pie(pajak,labels=perusahaan,autopct='%1.2f%%') 
plt.show()    
print("")


print("Soal No 3")
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000
csr1 = 0.025
csr2 = 0.035
hasil1 = (aset1 * csr1)
hasil2 = (aset2* csr2)
hasil3 = (aset3 * csr2)
hasil4 = (aset4 * csr2)
hasil5 = (aset5 * csr2)
print(" maka CSR prusahaan adalah : Rp."+ str(hasil1))
print(" maka CSR prusahaan adalah : Rp."+ str(hasil2))
print(" maka CSR prusahaan adalah : Rp."+ str(hasil3))
print(" maka CSR prusahaan adalah : Rp."+ str(hasil4))
print(" maka CSR prusahaan adalah : Rp."+ str(hasil5))
print("")


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [7000000.0, 10850000.000000002, 14700000.000000002, 19250000.0, 11900000.000000002]
c = ['red','black','blue','yellow']
plt.title("Total Pajak (pertahun) dan Utang setiap perusahaan")
ax.bar(perusahaan, pajak, color = c)            
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title(" Total CSR setiap perusahaan ") 
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]                                                
ax.pie(pajak,labels=perusahaan,autopct='%1.2f%%') 
plt.show()    
print("")


print("")
print("Soal No 4")
hasil1 = label1 * 12
hasil2 = label2 * 12
hasil3 = label3 * 12
hasil4 = label4 * 12
hasil5 = label5 * 12
hasil6 = hasil1 + hasil2 + hasil3 + hasil4 + hasil5
print(" maka laba perusahaan a-xis : Rp."+ str(hasil6))

print("")

print("Soal No 5")
hasil1 = (label1 * 12) - csr1 * 280000000 - (7500000 * 12) - 23375000.0
print("total pendapatan bersih pertahun perusahaan : rp." +str(hasil1))
hasil2 = (label2 * 12) - csr2 * 310000000 - (6090000 * 12) - 13330000.0
print("total pendapatan bersih pertahun perusahaan : rp." +str(hasil2))
hasil3 = (label3 * 12) - csr2 * 420000000 - (15400000 * 12) - 51660000.0
print("total pendapatan bersih pertahun perusahaan : rp." +str(hasil3))
hasil4 = (label4 * 12) - csr2 * 550000000- (27510000 * 12) - 62045000.0
print("total pendapatan bersih pertahun perusahaan : rp." +str(hasil4))
hasil5 = (label5 * 12) - csr2 * 340000000 - (8550000 * 12) - 11010000.0
print("total pendapatan bersih pertahun perusahaan : rp." +str(hasil5))

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [269625000.0,274740000.0,252840000.0,206585000.0,198490000.0]
c = ['red','green','blue','black','yellow']
plt.title("total pendapatan bersih pertahun perusahaan")
ax.bar(perusahaan, pajak, color = c)            
plt.show()

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data siswa PPD SMK AL-MADANI") 
perusahaan = ['A-Xis','B-Log','C-in','D-Namic','E-psilon']
pajak = [269625000.0,274740000.0,252840000.0,206585000.0,198490000.0]                                                  
ax.pie(pajak,labels=perusahaan,autopct='%1.2f%%') 
plt.show()
